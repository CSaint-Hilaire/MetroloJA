# %% [markdown]
# ## Import

# %%
from metroloja_lib import coreg_analyze as ca
from metroloja_lib import psf_analyze as pa
import tkinter as tk

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### *Select data*

# %%
master = tk.Tk()
master.geometry("400x200")
master.title('What analyze do you want to treat ?')

v = tk.StringVar(master)

def ShowChoice():
    global which_button_is_selected
    which_button_is_selected = v.get()

values = {"Résolution" : "1",
          "Coregistration" : "2",
          "Field Homogeneity" : "3",
          "Laser Power" : "4"}

tk.Label(master, 
         text="""Choose your plot :""",
         justify = tk.LEFT,
         padx = 20).pack()


for (text, value) in values.items():
    tk.Radiobutton(master, text = text, variable = v, value = value, indicator = 0, background = "light blue", command=ShowChoice).pack(fill = tk.X, ipady = 5, anchor=tk.W)


button = tk.Button(
    master,
    text="Get Selected",
    command=master.quit)

button.pack(fill=tk.X, padx=5, pady=5)





master.mainloop()
master.destroy()

if which_button_is_selected == '1': # Résolution part
    print('OK PSF')
    
    Input_folder = pa.select_folder() # Select input folder
    print('\n')
    Processed_folder = pa.processed_path(Input_folder[0], Input_folder[1]) # Find MetroloJ_QC Processed folder
    DF = pa.convert_to_df(Processed_folder, Input_folder[1], Input_folder[2], Input_folder[3], Input_folder[4], Input_folder[0]) # Creat dataframe containing all data
    # DF[0] => dataframe for XYZ data
    # DF[1] => dataframe for SBR data
    DF_XYZ_stat = pa.XYZ_stats(DF[0]) # Stat for XYZ data
    DF_SBR_stat = pa.SBR_stats(DF[1]) # Stat for SBR data
    print('\n')
    param_selected = pa.select_param() # Select analyze parameters to plot
    pa.display_selected_plot(param_selected[1], param_selected[0], DF[0], DF[1], DF_XYZ_stat, DF_SBR_stat[0], Input_folder[0], DF_SBR_stat[1])
    


    
elif which_button_is_selected == '2': # Coregistration part
    print('OK Coreg')
    
    Input_folder = ca.select_folder() # Select input folder
    print('\n')
    Processed_folder = ca.processed_path(Input_folder[0], Input_folder[1]) # Find MetroloJ_QC Processed folder
    DF = ca.convert_to_df(Processed_folder, Input_folder[1], Input_folder[2], Input_folder[3], Input_folder[4], Input_folder[0]) # Creat dataframe containing all data
    DF_stat = ca.coreg_stats(DF[0], DF[1]) # Dataframe for all stat
    print('\n')
    param_selected = ca.select_param() # Select analyze parameters to plot
    date_liste = DF[1]['Date'].tolist()
    ca.display_selected_plot(param_selected[1], param_selected[0], DF[0], DF_stat[0], Input_folder[0], DF_stat[1], DF[2], date_liste)
# Out:
# OK PSF
# Images name :
# Date 1
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_005
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_009
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_001
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_004
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_003
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_008
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_006
#    20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_007
# Date 2
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_008
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_003
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_001
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_002
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_006
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_004
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_009
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_005
#    20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU_007
# Date 3
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #03
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #07
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #06
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #02
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #01
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #04
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #05
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #09
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #10
#    20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001.czi - 20220411_PSF175LG_QUAREP_1518_LSM780_PMTCh2_001 #08
# Date 4
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_006
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_002
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_005
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_015
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_010
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_011
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_004
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_001
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_014
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_012
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_003
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_007
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_008
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_013
#    20220609_Invitrogen175nmQuarep_LSM880Curie_x63NA14_1518_1AU_009
#
#
# Path of processed folder :
#
# /home/pictbdd/Downloads/TestPourCadisha (copy)/TestPourCadisha/Confocal/LSM880_x63/PSF/20220103/Processed/20220103_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU
# /home/pictbdd/Downloads/TestPourCadisha (copy)/TestPourCadisha/Confocal/LSM880_x63/PSF/20220304/Processed/20220104_Sperotech175nmQuarep_LSM880Curie_x63NA14_1518_1AU
# /home/pictbdd/Downloads/TestPourCadisha (copy)/TestPourCadisha/Confocal/LSM880_x63/PSF/20220411/Processed/Process
# /home/pictbdd/Downloads/TestPourCadisha (copy)/TestPourCadisha/Confocal/LSM880_x63/PSF/20220609/Processed/Process
# |████████████████████████████████████████| 42/42 [100%] in 0.8s (53.04/s)
#
#
# Multiple Selection :
#   * FWHM
#   * off
#   * off
#   * off
# OK !
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6971/4177565170.py in <module>
#      50     DF_SBR_stat = pa.SBR_stats(DF[1]) # Stat for SBR data
#      51     print('\n')
# ---> 52     param_selected = pa.select_param() # Select analyze parameters to plot
#      53     pa.display_selected_plot(param_selected[2], param_selected[0], param_selected[1], DF[0], DF[1], DF_XYZ_stat, DF_SBR_stat[0], Input_folder[0], DF_SBR_stat[1])
#      54
#
# ~/metroloj_analysis/MetroloJA/metroloja_lib/psf_analyze.py in select_param()
#     559     print('OK !')
#     560
# --> 561     return(which_button_is_selected, selected_param, values)
#     562
#     563
#
# NameError: name 'which_button_is_selected' is not defined
